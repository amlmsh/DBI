# %% [markdown]
# # BGA I:  Kap. 3.2 - Einführung in die digitale Bildverarbeitung mit Python und openCV

# %% [markdown]
# ## Session 1: Einlesen und Darstellung von Bilddateien

# %% [markdown]
# Es wird mit dem allgemeinen Konfiguration der SW-Umgebung angefangen. Alle weieteren notebooks werden auf die gleiche Weise initialisiert. Dazu gehört in wesentlichen die Einbindung der Bibliotheken inkl. openCV und der Zugriff auf die Bilddateien.

# %% [markdown]
# <b>1. Schritt: Einbindung der Bibliotheken.</b><br>
# Beachten Sie, wir nutzen die Funktionalität von openCV für die Bildverarbeitung und die Funktionalität von Python zur Darstellung der Bilddaten und Grafiken.

# %%
import numpy as np
from glob import glob
from matplotlib import pyplot as plt

import cv2

# %% [markdown]
# <b>2. Sschritt: Zugriff auf Bilddaten.</b><br>
# Hier werden die Dateinamen inkl. relative Pfade der verwendeten Bilddateien in dem Feld <em>imgData</em> als String abgespeichert.

# %%
imgData = glob('../../../pics/imagingbook-images-de3/ch03/*.*')

# %%
imgData
# Out:
# ['../../../pics/imagingbook-images-de3/ch03/pix-jpeg.tif',
#  '../../../pics/imagingbook-images-de3/ch03/airfield-05small.tif',
#  '../../../pics/imagingbook-images-de3/ch03/croatia-02-small.tif',
#  '../../../pics/imagingbook-images-de3/ch03/fuji-histogram.jpg',
#  '../../../pics/imagingbook-images-de3/ch03/ireland-06-contrastnormal.tif',
#  '../../../pics/imagingbook-images-de3/ch03/flowers-05-red.tif',
#  '../../../pics/imagingbook-images-de3/ch03/flowers-05.tif',
#  '../../../pics/imagingbook-images-de3/ch03/ireland-06-dynamichigh.tif',
#  '../../../pics/imagingbook-images-de3/ch03/ireland-06-gray.tif',
#  '../../../pics/imagingbook-images-de3/ch03/flowers-05.jpg',
#  '../../../pics/imagingbook-images-de3/ch03/ireland-06-gif-gray-small.tif',
#  '../../../pics/imagingbook-images-de3/ch03/airfield-05.tif',
#  '../../../pics/imagingbook-images-de3/ch03/ireland-06-gif-gray.tif',
#  '../../../pics/imagingbook-images-de3/ch03/flowers-02gray.tif',
# ...

# %% [markdown]
# <b>3. Schritt: Auswahl eines Bildes. Über einen Indexwert wird der Pfadname aus dem Feld imgData gelesen</b><br>

# %%
imgData[6]
# Out:
# '../../../pics/imagingbook-images-de3/ch03/flowers-05.tif'

# %% [markdown]
# <b>4. Schritt: Einelsen der Daten eines Bildes aus der Bilddatei.</b><br>
# Es wird immer die Funktionalität von openCV verwendet, um Bilddateien einzulesen. Das Bild wird in der Variablen <em>image</em> abgespeichert.

# %%
image = cv2.imread(imgData[6])

# %% [markdown]
# <b>5. Schritt: Anzeigen des Bildes.</b><br>
# Für die Darstellung des Bildes verwenden wird hier immer die Python-Funktionlität verwendet. Diese wird von der Bibliothek <em>matplotlib</em> bereitgestellt.

# %%
plt.imshow(image)

# %% [markdown]
# <b>6. Schritt: Evaluation der angezeigten Daten. (Immer skeptisch sein.)</b><br>.
